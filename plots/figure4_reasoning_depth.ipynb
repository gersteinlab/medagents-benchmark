# %% [markdown]
# # Figure 4: Reasoning Depth
#
# This notebook runs the reasoning-depth annotation workflow and writes the generated figures into `plots/`.

# %%
from pathlib import Path
import os
import sys

repo_root = Path.cwd()
if not (repo_root / "plots").exists():
    repo_root = repo_root.parent

plots_dir = repo_root / "plots"
if str(plots_dir) not in sys.path:
    sys.path.insert(0, str(plots_dir))

os.chdir(repo_root)
repo_root

# %%
from annotate_reasoning_depth import main

dataset_stats, overall_kappa = main()
overall_kappa
